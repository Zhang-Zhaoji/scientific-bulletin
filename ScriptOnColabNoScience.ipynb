# %%
# !mkdir src
# !mkdir logs
# !mkdir getfiles

# %%
# 1. 首先安装必要的依赖
# !apt-get update -qq
# !apt-get install -y -qq wget unzip gnupg2 libglib2.0-0 libnss3 libgconf-2-4 \
    libfontconfig1 libxss1 libappindicator1 libindicator7 libosmesa6 \
    libcurl3-gnutls libcurl3-nss libcurl4 libgbm1 libgtk-3-0 libxkbcommon0 \
    libatspi2.0-0 libgtk-3-0 libxcomposite1 libxdamage1 libxfixes3 libxrandr2 \
    libasound2 libpangocairo-1.0-0 libpango-1.0-0 libatk1.0-0 libcairo-gobject2 \
    libcairo2 libgdk-pixbuf2.0-0 libglib2.0-0 libgtk-3-0 libgbm1 libxshmfence1

# 2. 安装 Chrome 浏览器（稳定版）
# !wget -q -O - https://dl-ssl.google.com/linux/linux_signing_key.pub | apt-key add -
# !echo "deb http://dl.google.com/linux/chrome/deb/ stable main" >> /etc/apt/sources.list.d/google.list
# !apt-get update -qq
# !apt-get install -y -qq google-chrome-stable

# 3. 安装匹配版本的 ChromeDriver
# !wget -q https://chromedriver.storage.googleapis.com/$(curl -sS https://chromedriver.storage.googleapis.com/LATEST_RELEASE)/chromedriver_linux64.zip
# !unzip -q chromedriver_linux64.zip
# !mv chromedriver /usr/local/bin/
# !chmod +x /usr/local/bin/chromedriver

# 4. 验证版本
# !google-chrome --version
# !chromedriver --version
# !pip install -q selenium webdriver-manager
# !pip install selenium
# !pip install jsonlines
# !pip install curl_cffi beautifulsoup4
# Out:
# W: Target Packages (main/binary-amd64/Packages) is configured multiple times in /etc/apt/sources.list.d/google-chrome.list:3 and /etc/apt/sources.list.d/google.list:1
# W: Target Packages (main/binary-all/Packages) is configured multiple times in /etc/apt/sources.list.d/google-chrome.list:3 and /etc/apt/sources.list.d/google.list:1
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# W: Target Packages (main/binary-amd64/Packages) is configured multiple times in /etc/apt/sources.list.d/google-chrome.list:3 and /etc/apt/sources.list.d/google.list:1
# W: Target Packages (main/binary-all/Packages) is configured multiple times in /etc/apt/sources.list.d/google-chrome.list:3 and /etc/apt/sources.list.d/google.list:1
# W: Target Packages (main/binary-amd64/Packages) is configured multiple times in /etc/apt/sources.list.d/google-chrome.list:3 and /etc/apt/sources.list.d/google.list:1
# W: Target Packages (main/binary-all/Packages) is configured multiple times in /etc/apt/sources.list.d/google-chrome.list:3 and /etc/apt/sources.list.d/google.list:1
# Warning: apt-key is deprecated. Manage keyring files in trusted.gpg.d instead (see apt-key(8)).
# OK
# W: Target Packages (main/binary-amd64/Packages) is configured multiple times in /etc/apt/sources.list.d/google-chrome.list:3 and /etc/apt/sources.list.d/google.list:1
# W: Target Packages (main/binary-all/Packages) is configured multiple times in /etc/apt/sources.list.d/google-chrome.list:3 and /etc/apt/sources.list.d/google.list:1
# W: Target Packages (main/binary-amd64/Packages) is configured multiple times in /etc/apt/sources.list.d/google-chrome.list:3 and /etc/apt/sources.list.d/google.list:2
# W: Target Packages (main/binary-all/Packages) is configured multiple times in /etc/apt/sources.list.d/google-chrome.list:3 and /etc/apt/sources.list.d/google.list:2
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# W: Target Packages (main/binary-amd64/Packages) is configured multiple times in /etc/apt/sources.list.d/google-chrome.list:3 and /etc/apt/sources.list.d/google.list:1
# W: Target Packages (main/binary-all/Packages) is configured multiple times in /etc/apt/sources.list.d/google-chrome.list:3 and /etc/apt/sources.list.d/google.list:1
# W: Target Packages (main/binary-amd64/Packages) is configured multiple times in /etc/apt/sources.list.d/google-chrome.list:3 and /etc/apt/sources.list.d/google.list:2
# W: Target Packages (main/binary-all/Packages) is configured multiple times in /etc/apt/sources.list.d/google-chrome.list:3 and /etc/apt/sources.list.d/google.list:2
# W: Target Packages (main/binary-amd64/Packages) is configured multiple times in /etc/apt/sources.list.d/google-chrome.list:3 and /etc/apt/sources.list.d/google.list:1
# W: Target Packages (main/binary-all/Packages) is configured multiple times in /etc/apt/sources.list.d/google-chrome.list:3 and /etc/apt/sources.list.d/google.list:1
# W: Target Packages (main/binary-amd64/Packages) is configured multiple times in /etc/apt/sources.list.d/google-chrome.list:3 and /etc/apt/sources.list.d/google.list:2
# W: Target Packages (main/binary-all/Packages) is configured multiple times in /etc/apt/sources.list.d/google-chrome.list:3 and /etc/apt/sources.list.d/google.list:2
# replace LICENSE.chromedriver? [y]es, [n]o, [A]ll, [N]one, [r]ename: N
#
# Google Chrome 146.0.7680.80
# ChromeDriver 114.0.5735.90 (386bc09e8f4f2e025eddae123f36f6263096ae49-refs/branch-heads/5735@{#1052})
# Requirement already satisfied: selenium in /usr/local/lib/python3.12/dist-packages (4.41.0)
# Requirement already satisfied: certifi>=2026.1.4 in /usr/local/lib/python3.12/dist-packages (from selenium) (2026.2.25)
# Requirement already satisfied: trio<1.0,>=0.31.0 in /usr/local/lib/python3.12/dist-packages (from selenium) (0.33.0)
# Requirement already satisfied: trio-websocket<1.0,>=0.12.2 in /usr/local/lib/python3.12/dist-packages (from selenium) (0.12.2)
# Requirement already satisfied: typing_extensions<5.0,>=4.15.0 in /usr/local/lib/python3.12/dist-packages (from selenium) (4.15.0)
# Requirement already satisfied: urllib3<3.0,>=2.6.3 in /usr/local/lib/python3.12/dist-packages (from urllib3[socks]<3.0,>=2.6.3->selenium) (2.6.3)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from selenium) (1.9.0)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from trio<1.0,>=0.31.0->selenium) (25.4.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.12/dist-packages (from trio<1.0,>=0.31.0->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from trio<1.0,>=0.31.0->selenium) (3.11)
# Requirement already satisfied: outcome in /usr/local/lib/python3.12/dist-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from trio<1.0,>=0.31.0->selenium) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.12/dist-packages (from trio-websocket<1.0,>=0.12.2->selenium) (1.3.2)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from urllib3[socks]<3.0,>=2.6.3->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.16.0 in /usr/local/lib/python3.12/dist-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium) (0.16.0)
# Requirement already satisfied: jsonlines in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonlines) (25.4.0)
# Requirement already satisfied: curl_cffi in /usr/local/lib/python3.12/dist-packages (0.14.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: cffi>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from curl_cffi) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /usr/local/lib/python3.12/dist-packages (from curl_cffi) (2026.2.25)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12.0->curl_cffi) (3.0)

# %%
# !pip install seleniumbase
# Out:
# Collecting seleniumbase
#   Downloading seleniumbase-4.47.3-py3-none-any.whl.metadata (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.6/88.6 kB 2.9 MB/s eta 0:00:00
# Collecting pip>=26.0.1 (from seleniumbase)
#   Downloading pip-26.0.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: packaging>=26.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (26.0)
# Collecting setuptools>=82.0.1 (from seleniumbase)
#   Downloading setuptools-82.0.1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: wheel>=0.46.3 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (0.46.3)
# Requirement already satisfied: attrs>=25.4.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (25.4.0)
# Requirement already satisfied: certifi>=2026.2.25 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (2026.2.25)
# Collecting exceptiongroup>=1.3.1 (from seleniumbase)
#   Downloading exceptiongroup-1.3.1-py3-none-any.whl.metadata (6.7 kB)
# Collecting websockets>=16.0 (from seleniumbase)
#   Downloading websockets-16.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (6.8 kB)
# Collecting filelock>=3.25.2 (from seleniumbase)
#   Downloading filelock-3.25.2-py3-none-any.whl.metadata (2.0 kB)
# Collecting fasteners>=0.20 (from seleniumbase)
#   Downloading fasteners-0.20-py3-none-any.whl.metadata (4.8 kB)
# Collecting mycdp>=1.3.4 (from seleniumbase)
#   Downloading mycdp-1.3.5-py3-none-any.whl.metadata (3.7 kB)
# Collecting pynose>=1.5.5 (from seleniumbase)
#   Downloading pynose-1.5.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: platformdirs>=4.9.4 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (4.9.4)
# Requirement already satisfied: typing-extensions>=4.15.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (4.15.0)
# Collecting sbvirtualdisplay>=1.4.0 (from seleniumbase)
#   Downloading sbvirtualdisplay-1.4.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=3.0.3 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.6 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (3.1.6)
# Requirement already satisfied: six>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (1.17.0)
# Collecting parse>=1.21.1 (from seleniumbase)
#   Downloading parse-1.21.1-py2.py3-none-any.whl.metadata (21 kB)
# Collecting parse-type>=0.6.6 (from seleniumbase)
#   Downloading parse_type-0.6.6-py2.py3-none-any.whl.metadata (12 kB)
# Collecting colorama>=0.4.6 (from seleniumbase)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pyyaml>=6.0.3 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (6.0.3)
# Requirement already satisfied: pygments>=2.19.2 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (2.19.2)
# Collecting tabcompleter>=1.4.0 (from seleniumbase)
#   Downloading tabcompleter-1.4.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting pdbp>=1.8.2 (from seleniumbase)
#   Downloading pdbp-1.8.2-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: idna>=3.11 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (3.11)
# Requirement already satisfied: charset-normalizer<4,>=3.4.5 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.26.20 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (2.6.3)
# Collecting requests~=2.32.5 (from seleniumbase)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: sniffio==1.3.1 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (1.3.1)
# Requirement already satisfied: h11==0.16.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (0.16.0)
# Requirement already satisfied: outcome==1.3.0.post0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (1.3.0.post0)
# Requirement already satisfied: trio<1,>=0.33.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (0.33.0)
# Requirement already satisfied: trio-websocket~=0.12.2 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (0.12.2)
# Requirement already satisfied: wsproto~=1.3.2 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (1.3.2)
# Requirement already satisfied: websocket-client~=1.9.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (1.9.0)
# Requirement already satisfied: selenium==4.41.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (4.41.0)
# Collecting cssselect<2,>=1.4.0 (from seleniumbase)
#   Downloading cssselect-1.4.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: nest-asyncio==1.6.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (1.6.0)
# Requirement already satisfied: sortedcontainers==2.4.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (2.4.0)
# Collecting execnet==2.1.2 (from seleniumbase)
#   Downloading execnet-2.1.2-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: iniconfig==2.3.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (2.3.0)
# Requirement already satisfied: pluggy==1.6.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (1.6.0)
# Collecting pytest==9.0.2 (from seleniumbase)
#   Downloading pytest-9.0.2-py3-none-any.whl.metadata (7.6 kB)
# Collecting pytest-html==4.0.2 (from seleniumbase)
#   Downloading pytest_html-4.0.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting pytest-metadata==3.1.1 (from seleniumbase)
#   Downloading pytest_metadata-3.1.1-py3-none-any.whl.metadata (8.6 kB)
# Collecting pytest-ordering==0.6 (from seleniumbase)
#   Downloading pytest_ordering-0.6-py3-none-any.whl.metadata (1.1 kB)
# Collecting pytest-rerunfailures==16.1 (from seleniumbase)
#   Downloading pytest_rerunfailures-16.1-py3-none-any.whl.metadata (21 kB)
# Collecting pytest-xdist==3.8.0 (from seleniumbase)
#   Downloading pytest_xdist-3.8.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting parameterized==0.9.0 (from seleniumbase)
#   Downloading parameterized-0.9.0-py2.py3-none-any.whl.metadata (18 kB)
# Collecting behave==1.2.6 (from seleniumbase)
#   Downloading behave-1.2.6-py2.py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: soupsieve~=2.8.3 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (2.8.3)
# Collecting beautifulsoup4~=4.14.3 (from seleniumbase)
#   Downloading beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting pyotp==2.9.0 (from seleniumbase)
#   Downloading pyotp-2.9.0-py3-none-any.whl.metadata (9.8 kB)
# Collecting python-xlib==0.33 (from seleniumbase)
#   Downloading python_xlib-0.33-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting PyAutoGUI>=0.9.54 (from seleniumbase)
#   Downloading PyAutoGUI-0.9.54.tar.gz (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 3.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: markdown-it-py==4.0.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (4.0.0)
# Requirement already satisfied: mdurl==0.1.2 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (0.1.2)
# Collecting rich<15,>=14.3.3 (from seleniumbase)
#   Downloading rich-14.3.3-py3-none-any.whl.metadata (18 kB)
# Collecting python3-Xlib (from PyAutoGUI>=0.9.54->seleniumbase)
#   Downloading python3-xlib-0.15.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.8/132.8 kB 7.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pymsgbox (from PyAutoGUI>=0.9.54->seleniumbase)
#   Downloading pymsgbox-2.0.1-py3-none-any.whl.metadata (4.4 kB)
# Collecting pytweening>=1.0.4 (from PyAutoGUI>=0.9.54->seleniumbase)
#   Downloading pytweening-1.2.0.tar.gz (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.2/171.2 kB 13.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pyscreeze>=0.1.21 (from PyAutoGUI>=0.9.54->seleniumbase)
#   Downloading pyscreeze-1.0.1.tar.gz (27 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pygetwindow>=0.0.5 (from PyAutoGUI>=0.9.54->seleniumbase)
#   Downloading PyGetWindow-0.0.9.tar.gz (9.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting mouseinfo (from PyAutoGUI>=0.9.54->seleniumbase)
#   Downloading MouseInfo-0.1.3.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pyrect (from pygetwindow>=0.0.5->PyAutoGUI>=0.9.54->seleniumbase)
#   Downloading PyRect-0.2.0.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from urllib3[socks]<3.0,>=2.6.3->selenium==4.41.0->seleniumbase) (1.7.1)
# Requirement already satisfied: pyperclip in /usr/local/lib/python3.12/dist-packages (from mouseinfo->PyAutoGUI>=0.9.54->seleniumbase) (1.11.0)
# Downloading seleniumbase-4.47.3-py3-none-any.whl (659 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 659.3/659.3 kB 22.9 MB/s eta 0:00:00
# Downloading behave-1.2.6-py2.py3-none-any.whl (136 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.8/136.8 kB 9.3 MB/s eta 0:00:00
# Downloading execnet-2.1.2-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.7/40.7 kB 2.0 MB/s eta 0:00:00
# Downloading parameterized-0.9.0-py2.py3-none-any.whl (20 kB)
# Downloading pyotp-2.9.0-py3-none-any.whl (13 kB)
# Downloading pytest-9.0.2-py3-none-any.whl (374 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.8/374.8 kB 22.8 MB/s eta 0:00:00
# Downloading pytest_html-4.0.2-py3-none-any.whl (23 kB)
# Downloading pytest_metadata-3.1.1-py3-none-any.whl (11 kB)
# Downloading pytest_ordering-0.6-py3-none-any.whl (4.6 kB)
# Downloading pytest_rerunfailures-16.1-py3-none-any.whl (14 kB)
# Downloading pytest_xdist-3.8.0-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 kB 2.2 MB/s eta 0:00:00
# Downloading python_xlib-0.33-py2.py3-none-any.whl (182 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.2/182.2 kB 11.3 MB/s eta 0:00:00
# Downloading beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.7/107.7 kB 7.0 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading cssselect-1.4.0-py3-none-any.whl (18 kB)
# Downloading exceptiongroup-1.3.1-py3-none-any.whl (16 kB)
# Downloading fasteners-0.20-py3-none-any.whl (18 kB)
# Downloading filelock-3.25.2-py3-none-any.whl (26 kB)
# Downloading mycdp-1.3.5-py3-none-any.whl (251 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.9/251.9 kB 13.7 MB/s eta 0:00:00
# Downloading parse-1.21.1-py2.py3-none-any.whl (19 kB)
# Downloading parse_type-0.6.6-py2.py3-none-any.whl (27 kB)
# Downloading pdbp-1.8.2-py3-none-any.whl (21 kB)
# Downloading pip-26.0.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 49.3 MB/s eta 0:00:00
# Downloading pynose-1.5.5-py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.7/130.7 kB 7.7 MB/s eta 0:00:00
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 4.3 MB/s eta 0:00:00
# Downloading rich-14.3.3-py3-none-any.whl (310 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.5/310.5 kB 16.8 MB/s eta 0:00:00
# Downloading sbvirtualdisplay-1.4.0-py3-none-any.whl (12 kB)
# Using cached setuptools-82.0.1-py3-none-any.whl (1.0 MB)
# Downloading tabcompleter-1.4.0-py3-none-any.whl (6.7 kB)
# Downloading websockets-16.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (184 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.9/184.9 kB 13.4 MB/s eta 0:00:00
# Downloading pymsgbox-2.0.1-py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: PyAutoGUI, pygetwindow, pyscreeze, pytweening, mouseinfo, python3-Xlib, pyrect
#   Building wheel for PyAutoGUI (pyproject.toml) ... done
#   Created wheel for PyAutoGUI: filename=pyautogui-0.9.54-py3-none-any.whl size=37683 sha256=18860d9cc74062ade98298e4d7b251068b0ebc61387650de36fc58350468c5a5
#   Stored in directory: /root/.cache/pip/wheels/d9/d6/47/04075995b093ecc87c212c9a3dbd34e59456c6fe504d65c3e4
#   Building wheel for pygetwindow (setup.py) ... done
#   Created wheel for pygetwindow: filename=PyGetWindow-0.0.9-py3-none-any.whl size=11063 sha256=c6abbcf7603aac1e5bf58c74a8a2122199852d02b86d6d0245ac87ed851a8bbf
#   Stored in directory: /root/.cache/pip/wheels/b3/39/81/34dd7a2eca5f885f1f6e2796761970daf66a2d98ac1904f5f4
#   Building wheel for pyscreeze (pyproject.toml) ... done
#   Created wheel for pyscreeze: filename=pyscreeze-1.0.1-py3-none-any.whl size=14457 sha256=5f1bef5919796afe66b7c1d45dc68afc7e071c368b243a9ac4231a06a46b85ec
#   Stored in directory: /root/.cache/pip/wheels/cd/3a/c2/7f2839239a069aa3c9564f6777cbb29d733720ef673f104f0d
#   Building wheel for pytweening (setup.py) ... done
#   Created wheel for pytweening: filename=pytweening-1.2.0-py3-none-any.whl size=8009 sha256=c4f228c31aeae20b2da45c7c7bc3dc9a374611c6070962a353dd1d75073bb9fa
#   Stored in directory: /root/.cache/pip/wheels/23/d5/13/4e9bdadbfe3c78e47c675e7410c0eed2fbb63c5ea6cf1b40e7
#   Building wheel for mouseinfo (setup.py) ... done
#   Created wheel for mouseinfo: filename=MouseInfo-0.1.3-py3-none-any.whl size=10888 sha256=7cbbb6b83855e24c32949d578eb160d4f7df1f5ddc9d6d75db4ac61940179da3
#   Stored in directory: /root/.cache/pip/wheels/b1/9b/f3/08650eb7f00af32f07789f3c6a101e0d7fc762b9891ae843bb
#   Building wheel for python3-Xlib (setup.py) ... done
#   Created wheel for python3-Xlib: filename=python3_xlib-0.15-py3-none-any.whl size=109501 sha256=5bdc4086a5b17dd59a99411bc8f6adeb4615f19d15a1430cfb230b97ccbf73b1
#   Stored in directory: /root/.cache/pip/wheels/a1/4c/74/f3627dc31a082129210025befb30084e73af761d007ac5c7b3
#   Building wheel for pyrect (setup.py) ... done
#   Created wheel for pyrect: filename=PyRect-0.2.0-py2.py3-none-any.whl size=11181 sha256=150313fc03af4fc018a689e93a4023e94bbaec07328a04d048f7d1191ad52993
#   Stored in directory: /root/.cache/pip/wheels/0b/1e/d7/0c74bd8f60b39c14d84e307398786002aa7ddc905927cc03c5
# Successfully built PyAutoGUI pygetwindow pyscreeze pytweening mouseinfo python3-Xlib pyrect
# Installing collected packages: pytweening, python3-Xlib, pyscreeze, pyrect, parse, websockets, tabcompleter, setuptools, sbvirtualdisplay, requests, python-xlib, pytest, pyotp, pynose, pymsgbox, pygetwindow, pip, parse-type, parameterized, mycdp, mouseinfo, filelock, fasteners, execnet, exceptiongroup, cssselect, colorama, beautifulsoup4, rich, pytest-xdist, pytest-rerunfailures, pytest-ordering, pytest-metadata, PyAutoGUI, pdbp, behave, pytest-html, seleniumbase
#   Attempting uninstall: websockets
#     Found existing installation: websockets 15.0.1
#     Uninstalling websockets-15.0.1:
#       Successfully uninstalled websockets-15.0.1
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: pytest
#     Found existing installation: pytest 8.4.2
#     Uninstalling pytest-8.4.2:
#       Successfully uninstalled pytest-8.4.2
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.25.1
#     Uninstalling filelock-3.25.1:
#       Successfully uninstalled filelock-3.25.1
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.13.5
#     Uninstalling beautifulsoup4-4.13.5:
#       Successfully uninstalled beautifulsoup4-4.13.5
#   Attempting uninstall: rich
#     Found existing installation: rich 13.9.4
#     Uninstalling rich-13.9.4:
#       Successfully uninstalled rich-13.9.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# bigframes 2.37.0 requires rich<14,>=12.4.4, but you have rich 14.3.3 which is incompatible.
# gradio-client 1.14.0 requires websockets<16.0,>=13.0, but you have websockets 16.0 which is incompatible.
# google-adk 1.26.0 requires websockets<16.0.0,>=15.0.1, but you have websockets 16.0 which is incompatible.
# Successfully installed PyAutoGUI-0.9.54 beautifulsoup4-4.14.3 behave-1.2.6 colorama-0.4.6 cssselect-1.4.0 exceptiongroup-1.3.1 execnet-2.1.2 fasteners-0.20 filelock-3.25.2 mouseinfo-0.1.3 mycdp-1.3.5 parameterized-0.9.0 parse-1.21.1 parse-type-0.6.6 pdbp-1.8.2 pip-26.0.1 pygetwindow-0.0.9 pymsgbox-2.0.1 pynose-1.5.5 pyotp-2.9.0 pyrect-0.2.0 pyscreeze-1.0.1 pytest-9.0.2 pytest-html-4.0.2 pytest-metadata-3.1.1 pytest-ordering-0.6 pytest-rerunfailures-16.1 pytest-xdist-3.8.0 python-xlib-0.33 python3-Xlib-0.15 pytweening-1.2.0 requests-2.32.5 rich-14.3.3 sbvirtualdisplay-1.4.0 seleniumbase-4.47.3 setuptools-82.0.1 tabcompleter-1.4.0 websockets-16.0

# %%
# !apt-get update
# !apt-get install -y xvfb
# !pip install pyvirtualdisplay seleniumbase
# Out:
# Hit:1 https://dl.google.com/linux/chrome/deb stable InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://cli.github.com/packages stable InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Target Packages (main/binary-amd64/Packages) is configured multiple times in /etc/apt/sources.list.d/google-chrome.list:3 and /etc/apt/sources.list.d/google.list:1
# W: Target Packages (main/binary-all/Packages) is configured multiple times in /etc/apt/sources.list.d/google-chrome.list:3 and /etc/apt/sources.list.d/google.list:1
# W: Target Packages (main/binary-amd64/Packages) is configured multiple times in /etc/apt/sources.list.d/google-chrome.list:3 and /etc/apt/sources.list.d/google.list:2
# W: Target Packages (main/binary-all/Packages) is configured multiple times in /etc/apt/sources.list.d/google-chrome.list:3 and /etc/apt/sources.list.d/google.list:2
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# W: Target Packages (main/binary-amd64/Packages) is configured multiple times in /etc/apt/sources.list.d/google-chrome.list:3 and /etc/apt/sources.list.d/google.list:1
# W: Target Packages (main/binary-all/Packages) is configured multiple times in /etc/apt/sources.list.d/google-chrome.list:3 and /etc/apt/sources.list.d/google.list:1
# W: Target Packages (main/binary-amd64/Packages) is configured multiple times in /etc/apt/sources.list.d/google-chrome.list:3 and /etc/apt/sources.list.d/google.list:2
# W: Target Packages (main/binary-all/Packages) is configured multiple times in /etc/apt/sources.list.d/google-chrome.list:3 and /etc/apt/sources.list.d/google.list:2
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# 0 upgraded, 0 newly installed, 0 to remove and 121 not upgraded.
# W: Target Packages (main/binary-amd64/Packages) is configured multiple times in /etc/apt/sources.list.d/google-chrome.list:3 and /etc/apt/sources.list.d/google.list:1
# W: Target Packages (main/binary-all/Packages) is configured multiple times in /etc/apt/sources.list.d/google-chrome.list:3 and /etc/apt/sources.list.d/google.list:1
# W: Target Packages (main/binary-amd64/Packages) is configured multiple times in /etc/apt/sources.list.d/google-chrome.list:3 and /etc/apt/sources.list.d/google.list:2
# W: Target Packages (main/binary-all/Packages) is configured multiple times in /etc/apt/sources.list.d/google-chrome.list:3 and /etc/apt/sources.list.d/google.list:2
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl.metadata (943 bytes)
# Requirement already satisfied: seleniumbase in /usr/local/lib/python3.12/dist-packages (4.47.3)
# Requirement already satisfied: pip>=26.0.1 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (26.0.1)
# Requirement already satisfied: packaging>=26.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (26.0)
# Requirement already satisfied: setuptools>=82.0.1 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (82.0.1)
# Requirement already satisfied: wheel>=0.46.3 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (0.46.3)
# Requirement already satisfied: attrs>=25.4.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (25.4.0)
# Requirement already satisfied: certifi>=2026.2.25 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (2026.2.25)
# Requirement already satisfied: exceptiongroup>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (1.3.1)
# Requirement already satisfied: websockets>=16.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (16.0)
# Requirement already satisfied: filelock>=3.25.2 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (3.25.2)
# Requirement already satisfied: fasteners>=0.20 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (0.20)
# Requirement already satisfied: mycdp>=1.3.4 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (1.3.5)
# Requirement already satisfied: pynose>=1.5.5 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (1.5.5)
# Requirement already satisfied: platformdirs>=4.9.4 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (4.9.4)
# Requirement already satisfied: typing-extensions>=4.15.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (4.15.0)
# Requirement already satisfied: sbvirtualdisplay>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (1.4.0)
# Requirement already satisfied: MarkupSafe>=3.0.3 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.6 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (3.1.6)
# Requirement already satisfied: six>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (1.17.0)
# Requirement already satisfied: parse>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (1.21.1)
# Requirement already satisfied: parse-type>=0.6.6 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (0.6.6)
# Requirement already satisfied: colorama>=0.4.6 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (0.4.6)
# Requirement already satisfied: pyyaml>=6.0.3 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (6.0.3)
# Requirement already satisfied: pygments>=2.19.2 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (2.19.2)
# Requirement already satisfied: tabcompleter>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (1.4.0)
# Requirement already satisfied: pdbp>=1.8.2 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (1.8.2)
# Requirement already satisfied: idna>=3.11 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (3.11)
# Requirement already satisfied: charset-normalizer<4,>=3.4.5 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.26.20 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (2.6.3)
# Requirement already satisfied: requests~=2.32.5 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (2.32.5)
# Requirement already satisfied: sniffio==1.3.1 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (1.3.1)
# Requirement already satisfied: h11==0.16.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (0.16.0)
# Requirement already satisfied: outcome==1.3.0.post0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (1.3.0.post0)
# Requirement already satisfied: trio<1,>=0.33.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (0.33.0)
# Requirement already satisfied: trio-websocket~=0.12.2 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (0.12.2)
# Requirement already satisfied: wsproto~=1.3.2 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (1.3.2)
# Requirement already satisfied: websocket-client~=1.9.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (1.9.0)
# Requirement already satisfied: selenium==4.41.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (4.41.0)
# Requirement already satisfied: cssselect<2,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (1.4.0)
# Requirement already satisfied: nest-asyncio==1.6.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (1.6.0)
# Requirement already satisfied: sortedcontainers==2.4.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (2.4.0)
# Requirement already satisfied: execnet==2.1.2 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (2.1.2)
# Requirement already satisfied: iniconfig==2.3.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (2.3.0)
# Requirement already satisfied: pluggy==1.6.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (1.6.0)
# Requirement already satisfied: pytest==9.0.2 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (9.0.2)
# Requirement already satisfied: pytest-html==4.0.2 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (4.0.2)
# Requirement already satisfied: pytest-metadata==3.1.1 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (3.1.1)
# Requirement already satisfied: pytest-ordering==0.6 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (0.6)
# Requirement already satisfied: pytest-rerunfailures==16.1 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (16.1)
# Requirement already satisfied: pytest-xdist==3.8.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (3.8.0)
# Requirement already satisfied: parameterized==0.9.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (0.9.0)
# Requirement already satisfied: behave==1.2.6 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (1.2.6)
# Requirement already satisfied: soupsieve~=2.8.3 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (2.8.3)
# Requirement already satisfied: beautifulsoup4~=4.14.3 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (4.14.3)
# Requirement already satisfied: pyotp==2.9.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (2.9.0)
# Requirement already satisfied: python-xlib==0.33 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (0.33)
# Requirement already satisfied: PyAutoGUI>=0.9.54 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (0.9.54)
# Requirement already satisfied: markdown-it-py==4.0.0 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (4.0.0)
# Requirement already satisfied: mdurl==0.1.2 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (0.1.2)
# Requirement already satisfied: rich<15,>=14.3.3 in /usr/local/lib/python3.12/dist-packages (from seleniumbase) (14.3.3)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from urllib3[socks]<3.0,>=2.6.3->selenium==4.41.0->seleniumbase) (1.7.1)
# Requirement already satisfied: python3-Xlib in /usr/local/lib/python3.12/dist-packages (from PyAutoGUI>=0.9.54->seleniumbase) (0.15)
# Requirement already satisfied: pymsgbox in /usr/local/lib/python3.12/dist-packages (from PyAutoGUI>=0.9.54->seleniumbase) (2.0.1)
# Requirement already satisfied: pytweening>=1.0.4 in /usr/local/lib/python3.12/dist-packages (from PyAutoGUI>=0.9.54->seleniumbase) (1.2.0)
# Requirement already satisfied: pyscreeze>=0.1.21 in /usr/local/lib/python3.12/dist-packages (from PyAutoGUI>=0.9.54->seleniumbase) (1.0.1)
# Requirement already satisfied: pygetwindow>=0.0.5 in /usr/local/lib/python3.12/dist-packages (from PyAutoGUI>=0.9.54->seleniumbase) (0.0.9)
# Requirement already satisfied: mouseinfo in /usr/local/lib/python3.12/dist-packages (from PyAutoGUI>=0.9.54->seleniumbase) (0.1.3)
# Requirement already satisfied: pyrect in /usr/local/lib/python3.12/dist-packages (from pygetwindow>=0.0.5->PyAutoGUI>=0.9.54->seleniumbase) (0.2.0)
# Requirement already satisfied: pyperclip in /usr/local/lib/python3.12/dist-packages (from mouseinfo->PyAutoGUI>=0.9.54->seleniumbase) (1.11.0)
# Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyvirtualdisplay
# Successfully installed pyvirtualdisplay-3.0

# %%
# !python src/main.py
# Out:
# ================================================================================
# Fetching from arXiv...
# Categories: q-bio.NC, q-bio.TO, q-bio.MN
# Date range: last 7 days only (strict)
# ================================================================================
# Fetching arXiv papers for category: q-bio.NC
#   Found 17 papers in last 7 days
# Fetching arXiv papers for category: q-bio.TO
#   Found 1 papers in last 7 days
# Fetching arXiv papers for category: q-bio.MN
#   Found 4 papers in last 7 days
# Total arXiv papers: 22
#
# ================================================================================
# Fetching from Nature journals (last 7 days)...
# ================================================================================
#
# [1/10] Processing: https://www.nature.com/nature/research-articles
# Fetching articles from https://www.nature.com/nature/research-articles
# Fetching articles from last 7 days (since 07/03/2026)
# page 1
#   Found 20 articles on this page
#     [+] 2026-03-11 - The dynamic basis of G-protein recognition and act...
#     [+] 2026-03-11 - A large-scale coherent 4D imaging sensor...
#     [+] 2026-03-11 - Capturing dynamic phage–pathogen coevolution by cl...
#     [+] 2026-03-11 - Multidimensional profiling of heterogeneity in sup...
#     [+] 2026-03-11 - Structures of Marburgvirus glycoprotein and its co...
#     [+] 2026-03-11 - Multimodal electron microscopy of halide perovskit...
#     [+] 2026-03-11 - Lense–Thirring precessing magnetar engine drives a...
#     [+] 2026-03-11 - Facile induction of immune tolerance by an interle...
#     [+] 2026-03-11 - Snapshots of the dynamic basis of NTSR1 G protein ...
#     [+] 2026-03-11 - Intestinal interoceptive dysfunction drives age-as...
#     [+] 2026-03-11 - Assembly of helper NLR resistosome clusters upon a...
#     [+] 2026-03-11 - A sorghum pangenome reference improves global crop...
#     [+] 2026-03-11 - B cell imprinting in children impairs antibodies t...
#     [+] 2026-03-11 - Nanophotonic waveguide chip-to-world beam scanning...
#     [+] 2026-03-11 - A big-push community intervention reduced rates of...
#     [+] 2026-03-11 - Immune evasive DNA donors and recombinases license...
#     [+] 2026-03-11 - Natural maternal immunity protects neonates from E...
#     [+] 2026-03-11 - Ageing promotes metastasis via activation of the i...
#     [+] 2026-03-11 - Risk-adaptive therapy guided by dynamic ctDNA in n...
#     [+] 2026-03-11 - Gene conversion empowers natural selection in a cl...
# page 2
#   Found 20 articles on this page
#     [+] 2026-03-11 - A mechanism to initiate emergency type 2 myelopoie...
#     [+] 2026-03-10 - Maximizing carrier extraction in hybrid back-conta...
#     [+] 2026-03-10 - Alcohol group migration by proximity-enhanced H at...
#     [+] 2026-03-04 - Shared neural substrates of prosocial and parentin...
#     [+] 2026-03-04 - Genome modelling and design across all domains of ...
#     [+] 2026-03-04 - DICER cleavage fidelity is governed by 5′-end bind...
#     [+] 2026-03-04 - Limited thermal tolerance in tropical insects and ...
#     [+] 2026-03-04 - A metabolic alarmin from keratinocytes potentiates...
#     [+] 2026-03-04 - Long-term thrombus-free left atrial appendage occl...
#     [+] 2026-03-04 - Lipid metabolism drives dietary effects on T cell ...
#     [+] 2026-03-04 - Merlin: a computed tomography vision–language foun...
#     [+] 2026-03-04 - Microbiota-mediated induction of beige adipocytes ...
#     [+] 2026-03-04 - Mechanism of co-transcriptional cap snatching by i...
#     [+] 2026-03-04 - Cell-free chromatin state tracing reveals disease ...
#     [+] 2026-03-04 - The oldest articulated bony fish from the early Si...
#     [+] 2026-03-04 - Bulk hexagonal diamond...
#     [+] 2026-03-04 - Sea level much higher than assumed in most coastal...
#     [+] 2026-03-04 - A glucocorticoid–FAS axis controls immune evasion ...
#     [+] 2026-03-04 - The molecular basis of force selectivity by PIEZO2...
#     [+] 2026-03-04 - Advancing operational global aerosol forecasting w...
# page 3
#   Found 18 articles on this page
#     [+] 2026-03-04 - Wind shear enhances soil moisture influence on rap...
#     [+] 2026-03-04 - Structural basis of RNA-guided transcription by a ...
#     [+] 2026-03-04 - Homologous recombination deficiency and hemizygosi...
#     [+] 2026-03-04 - Exapted CRISPR–Cas12f homologues drive RNA-guided ...
#     [+] 2026-03-04 - Wide-swath altimetry maps bank shapes and storage ...
#     [+] 2026-03-04 - Largest Silurian fish illuminates the origin of os...
#     [+] 2026-03-04 - Precancerous niche remodelling dictates nascent tu...
#     [-] 2026-03-03 - Too old, stopping
# Fetching abstracts for 47 articles...
# 100% 47/47 [01:10<00:00,  1.51s/it]
#   -> Found 47 papers
#
# [2/10] Processing: https://www.nature.com/nature/reviews-and-analysis
# Fetching articles from https://www.nature.com/nature/reviews-and-analysis
# Fetching articles from last 7 days (since 07/03/2026)
# page 1
#   Found 0 articles on this page
#   Less than 5 articles on page, stopping
# Total articles collected: 0
#   -> Found 0 papers
#
# [3/10] Processing: https://www.nature.com/natbiomedeng/research-articles
# Fetching articles from https://www.nature.com/natbiomedeng/research-articles
# Fetching articles from last 7 days (since 07/03/2026)
# page 1
#   Found 20 articles on this page
#     [+] 2026-03-11 - DNA origami vaccine nanoparticles improve humoral ...
#     [+] 2026-03-11 - Perilesional neuromodulation replaces lost sensori...
#     [+] 2026-03-11 - Rapid and sensitive detection of cancer-derived sm...
#     [+] 2026-03-09 - Predictive biomarkers of response to chimeric anti...
#     [-] 2026-03-03 - Too old, stopping
# Fetching abstracts for 4 articles...
# 100% 4/4 [00:06<00:00,  1.57s/it]
#   -> Found 4 papers
#
# [4/10] Processing: https://www.nature.com/natbiomedeng/reviews-and-analysis
# Fetching articles from https://www.nature.com/natbiomedeng/reviews-and-analysis
# Fetching articles from last 7 days (since 07/03/2026)
# page 1
#   Found 5 articles on this page
#     [-] 2026-01-15 - Too old, stopping
#   -> Found 0 papers
#
# [5/10] Processing: https://www.nature.com/nmeth/research-articles
# Fetching articles from https://www.nature.com/nmeth/research-articles
# Fetching articles from last 7 days (since 07/03/2026)
# page 1
#   Found 17 articles on this page
#     [+] 2026-03-12 - Connectome-seq: high-throughput mapping of neurona...
#     [+] 2026-03-12 - Highly accurate ab initio gene annotation with ANN...
#     [+] 2026-03-12 - stVCR: spatiotemporal dynamics of single cells...
#     [+] 2026-03-12 - Isotonic and minimally invasive optical clearing m...
#     [+] 2026-03-11 - AF2BIND: predicting small-molecule binding sites u...
#     [+] 2026-03-09 - Scaffolds with optimized quaternary symmetry for d...
#     [-] 2026-03-02 - Too old, stopping
# Fetching abstracts for 6 articles...
# 100% 6/6 [00:08<00:00,  1.50s/it]
#   -> Found 6 papers
#
# [6/10] Processing: https://www.nature.com/nmeth/reviews-and-analysis
# Fetching articles from https://www.nature.com/nmeth/reviews-and-analysis
# Fetching articles from last 7 days (since 07/03/2026)
# page 1
#   Found 3 articles on this page
#     [-] 2025-12-31 - Too old, stopping
#   -> Found 0 papers
#
# [7/10] Processing: https://www.nature.com/neuro/research-articles
# Fetching articles from https://www.nature.com/neuro/research-articles
# Fetching articles from last 7 days (since 07/03/2026)
# page 1
#   Found 17 articles on this page
#     [+] 2026-03-11 - Deconstruction of a memory engram reveals distinct...
#     [+] 2026-03-11 - Competitive interactions shape mammalian brain net...
#     [+] 2026-03-10 - Persistent interferon signaling causes sensory neu...
#     [+] 2026-03-10 - Neuronal tuning aligns dynamically with object and...
#     [+] 2026-03-09 - A neural signature of adaptive mentalization...
#     [-] 2026-02-26 - Too old, stopping
# Fetching abstracts for 5 articles...
# 100% 5/5 [00:07<00:00,  1.58s/it]
#   -> Found 5 papers
#
# [8/10] Processing: https://www.nature.com/neuro/reviews-and-analysis
# Fetching articles from https://www.nature.com/neuro/reviews-and-analysis
# Fetching articles from last 7 days (since 07/03/2026)
# page 1
#   Found 1 articles on this page
#     [-] 2026-02-20 - Too old, stopping
#   -> Found 0 papers
#
# [9/10] Processing: https://www.nature.com/nathumbehav/research-articles
# Fetching articles from https://www.nature.com/nathumbehav/research-articles
# Fetching articles from last 7 days (since 07/03/2026)
# page 1
#   Found 18 articles on this page
#     [+] 2026-03-13 - Optimized feature gains explain and predict succes...
#     [-] 2026-03-02 - Too old, stopping
# Fetching abstracts for 1 articles...
# 100% 1/1 [00:01<00:00,  1.53s/it]
#   -> Found 1 papers
#
# [10/10] Processing: https://www.nature.com/nathumbehav/reviews-and-analysis
# Fetching articles from https://www.nature.com/nathumbehav/reviews-and-analysis
# Fetching articles from last 7 days (since 07/03/2026)
# page 1
#   Found 0 articles on this page
#   Less than 5 articles on page, stopping
# Total articles collected: 0
#   -> Found 0 papers
#
# Total Nature papers: 63
#
# ================================================================================
# Fetching from Cell Press journals...
# ================================================================================
# ================================================================================
# Cell Press Crawler - Neuron
# ================================================================================
# Fetching: https://www.cell.com/neuron/current
# Fetched 355179 chars via Selenium
# Found 15 article elements with .toc__item
# Extracted 15 research articles
# ================================================================================
# Cell Press Crawler - Current Biology
# ================================================================================
# Fetching: https://www.cell.com/current-biology/current
# Fetched 401540 chars via Selenium
# Found 39 article elements with .toc__item
# Extracted 39 research articles
# ================================================================================
# Cell Press Crawler - Trends in Neurosciences
# ================================================================================
# Fetching: https://www.cell.com/trends/neurosciences/current
# Fetched 345729 chars via Selenium
# Found 11 article elements with .toc__item
# Extracted 10 research articles
#
# ================================================================================
# Enriching with Europe PMC...
# ================================================================================
#
# Enriching 64 papers...
# ================================================================================
#
# [1/64]  Enriching: Lost rhythms: Breast cancer hijacks neuronal circuits that blunt GC rh...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [2/64]  Enriching: MS4A4A and MS4A6A: New targets to enhance microglia protective functio...
#     Trying Europe PMC (title search)...
#     [SKIP] Title similarity too low (0.08)
#     Trying preprint servers...
#     [NOT FOUND] Keeping original data (no abstract)
#
# [3/64]  Enriching: A genetic architect of opioid responses: Microglial Runx1...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [4/64]  Enriching: From syllables to states: Hierarchical organization of self-motivated ...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [5/64]  Enriching: Before the first bite: Do olfactory expectations shape gastric feeling...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [6/64]  Enriching: How heterogeneity shapes dynamics and computation in the brain...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [7/64]  Enriching: Aberrant hypothalamic neuronal activity blunts glucocorticoid diurnal ...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [8/64]  Enriching: The Alzheimer’s disease risk genes MS4A4A and MS4A6A cooperate to nega...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [9/64]  Enriching: Aberrant nuclear pore complex degradation contributes to neurodegenera...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [10/64]  Enriching: CLN3 mediates chloride efflux from lysosomes...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [11/64]  Enriching: CB1R and GlyT2 interaction in spinal glycinergic circuits drives neuro...
#     Trying Europe PMC (title search)...
#     [SKIP] Title similarity too low (0.00)
#     Trying preprint servers...
#     [NOT FOUND] Keeping original data (no abstract)
#
# [12/64]  Enriching: Runx1 transcription factor modulates opioid analgesia and withdrawal i...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [13/64]  Enriching: Spontaneous behavior is a succession of self-directed tasks...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [14/64]  Enriching: Macaque prefrontal cortex integrates multiple components for metacogni...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [15/64]  Enriching: A neural circuit framework for economic choice: From building blocks o...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [16/64]  Enriching: An ancient disease from the New World...
#     Trying Europe PMC (title search)...
#     [SKIP] Title similarity too low (0.11)
#     Trying preprint servers...
#     [NOT FOUND] Keeping original data (no abstract)
#
# [17/64]  Enriching: Antonio García-Bellido (1936–2025)...
#     Trying Europe PMC (title search)...
#     [SKIP] Title similarity too low (0.50)
#     Trying preprint servers...
#     [NOT FOUND] Keeping original data (no abstract)
#
# [18/64]  Enriching: The biology of musicality...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [19/64]  Enriching: Mark C. Fishman...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [20/64]  Enriching: Nocturnality...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [21/64]  Enriching: Human vision maintains a rich representation of objects moving behind ...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [22/64]  Enriching: Public communication alters private confidence...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [23/64]  Enriching: Behavioral evolution: Brief moments of inhibition guide mate choice...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [24/64]  Enriching: Plant biology: The changing face of starch...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [25/64]  Enriching: Torpor: White-backed swallows snooze through the rain...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [26/64]  Enriching: Topographic mapping: The making and breaking of adhesive nets...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [27/64]  Enriching: Paleontology: A diverse biota in the shadow of a mass extinction?...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [28/64]  Enriching: Evolution: Shark and ray biodiversity in deep time...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [29/64]  Enriching: Fungal symbioses: A multiplicity of fungi in the lichen union...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [30/64]  Enriching: Behavioral ecology: Tracking the flight of the foraging honey bee...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [31/64]  Enriching: Developmental tolerance and disease implications of aneuploidy...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [32/64]  Enriching: Selective adhesion preserves eye patterning as axonal retinotopy in th...
#     Trying Europe PMC (title search)...
#     Trying preprint servers...
#     [NOT FOUND] Keeping original data (no abstract)
#
# [33/64]  Enriching: Changes in age-related sexual selection in a humpback whale population...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [34/64]  Enriching: Dispersal and isolation of the scaly-foot snail across abyssal insular...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [35/64]  Enriching: Compound starch granule formation in grass seeds is associated with di...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [36/64]  Enriching: Non-linear stress-softening of peptidoglycan mediates bacterial cell s...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [37/64]  Enriching: Homeostatic preservation of action potential waveform by Notch and Ner...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [38/64]  Enriching: Spiral phyllotaxis in the mossPhyscomitrium patensemerges from simple ...
#     Trying Europe PMC (title search)...
#     Trying preprint servers...
#     [NOT FOUND] Keeping original data (no abstract)
#
# [39/64]  Enriching: Immune activation suppresses reproductive growth inArabidopsisthrough ...
#     Trying Europe PMC (title search)...
#     Trying preprint servers...
#     [NOT FOUND] Keeping original data (no abstract)
#
# [40/64]  Enriching: Regulation of mitophagy by Fis1 and Fascin1-organized actin...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [41/64]  Enriching: Mapping concept and relational semantic representation in the brain us...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [42/64]  Enriching: Repeated evolution of supergenes on an ancient social chromosome...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [43/64]  Enriching: Strain variation identifies a neural substrate for behavioral evolutio...
#     Trying Europe PMC (title search)...
#     [SKIP] Title similarity too low (0.00)
#     Trying preprint servers...
#     [NOT FOUND] Keeping original data (no abstract)
#
# [44/64]  Enriching: Thermal-state-dependent control of body temperature and feeding by two...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [45/64]  Enriching: Torpor in a passerine bird expands the scope of avian heterothermy...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [46/64]  Enriching: The earliest reptile body impressions with scaly skin...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [47/64]  Enriching: Sequencing of distinct wing behaviors duringDrosophilacourtship...
#     Trying Europe PMC (title search)...
#     Trying preprint servers...
#     [NOT FOUND] Keeping original data (no abstract)
#
# [48/64]  Enriching: Social interactions in medaka fish depend on discrete kinematic states...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [49/64]  Enriching: Genetic hotspots for conserving Southern Ocean benthic biodiversity...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [50/64]  Enriching: Precise, individualized foraging flights in honeybees revealed by mult...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [51/64]  Enriching: Evolution of competitiveness during wheat domestication...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [52/64]  Enriching: Broad skill generalization with an extra robotic body part...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [53/64]  Enriching: Visual attention in peripersonal space is dependent on differential mo...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [54/64]  Enriching: A novel kleptoplastidic symbiosis revealed in the marine centrohelidMe...
#     Trying Europe PMC (title search)...
#     Trying preprint servers...
#     [NOT FOUND] Keeping original data (no abstract)
#
# [55/64]  Enriching: From illness to rest: neural circuits linking sickness and sleep...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [56/64]  Enriching: CHCHD2 links mitochondrial dysfunction and α-synuclein misfolding in P...
#     Trying Europe PMC (title search)...
#     [SKIP] Title similarity too low (0.17)
#     Trying preprint servers...
#     [NOT FOUND] Keeping original data (no abstract)
#
# [57/64]  Enriching: Timing is everything: myelin and coincidence detection...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [58/64]  Enriching: A dual-function framework of interoception: the information and coordi...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [59/64]  Enriching: A neurobiological perspective on prolonged grief disorder...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [60/64]  Enriching: Micro- and nanoplastics in neurological dysfunction...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [61/64]  Enriching: Phagocytosis and neuroinflammation: orchestrating central nervous syst...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [62/64]  Enriching: Challenges and opportunities in adapting high-throughput functional as...
#     Trying Europe PMC (title search)...
#     Trying preprint servers...
#     [NOT FOUND] Keeping original data (no abstract)
#
# [63/64]  Enriching: Making of BDNF: role of promoters, enhancers, and untranslated regions...
#     Trying Europe PMC (title search)...
#     [OK] Found in Europe PMC by title (similarity: 1.00)
#
# [64/64]  Enriching: Subscription and Copyright Information...
#     Trying Europe PMC (title search)...
#     [SKIP] Title similarity too low (0.06)
#     Trying preprint servers...
#     [NOT FOUND] Keeping original data (no abstract)
#
# ================================================================================
# Enrichment Summary:
#   Total papers: 64
#   Europe PMC (DOI): 0
#   Europe PMC (title): 51
#   Preprint servers: 0
#   Original only: 13
#   Errors: 0
#
# Total Cell Press papers: 64
#
# Enrichment breakdown:
#   europepmc_title: 51
#   original_only: 13
#
# ================================================================================
# Merging and deduplicating papers...
# ================================================================================
# Total papers before deduplication: 149
# Duplicates removed: 0
# Unique papers: 149
#
# Saved merged papers to: getfiles/all_papers_2026-03-14.jsonl
# File size: 237595 bytes
# Saved summary to: getfiles/summary_2026-03-14.json
#
# ================================================================================
# CRAWL SUMMARY
# ================================================================================
#
# Source                    Count
# --------------------------------
# arXiv                        22
# bioRxiv                       0
# Nature Journals              63
# Science                       0
# Cell Press                   64
# --------------------------------
# Total (before dedup)        149
# Unique papers               149
#
# Date range: 04 Mar 2026 to 14 Mar 2026
#
# ================================================================================
# SAMPLE PAPERS (Newest 3)
# ================================================================================
#
# [1] [Neuron + Europe PMC] Lost rhythms: Breast cancer hijacks neuronal circuits that blunt GC rh...
#     Authors: Francesco De Virgiliis, Christoph Scheiermann
#     Date: 14 Mar 2026
#
# [2] [Neuron] MS4A4A and MS4A6A: New targets to enhance microglia protective functio...
#     Authors: David V. Hansen, Celeste M. Karch, Drishya Mainali...
#     Date: 14 Mar 2026
#
# [3] [Neuron + Europe PMC] A genetic architect of opioid responses: Microglial Runx1...
#     Authors: Dong Dong, Longzhen Cheng
#     Date: 14 Mar 2026
#
# [OK] Done!
